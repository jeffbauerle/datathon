# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_pickle('../data/new_features.pkl')

# %%
df.head(20)
# Out:
#                   created_at                   id               id_str  \
# 0  2020-09-29 23:59:56+00:00  1311093385688735744  1311093385688735744
# 1  2020-09-29 23:59:58+00:00  1311093394400333824  1311093394400333824
# 2  2020-09-30 00:00:00+00:00  1311093401652277252  1311093401652277248
# 3  2020-09-30 00:00:02+00:00  1311093410737070086  1311093410737070080
# 4  2020-09-30 00:00:04+00:00  1311093419100561408  1311093419100561408
# 5  2020-09-30 00:00:06+00:00  1311093427434446853  1311093427434446848
# 6  2020-09-30 00:00:08+00:00  1311093435844222982  1311093435844222976
# 7  2020-09-30 00:00:10+00:00  1311093442592743424  1311093442592743424
# 8  2020-09-30 00:00:11+00:00  1311093449135972353  1311093449135972352
# 9  2020-09-30 00:00:13+00:00  1311093457365200896  1311093457365200896
# 10 2020-09-30 00:00:15+00:00  1311093465682386944  1311093465682386944
# 11 2020-09-30 00:00:17+00:00  1311093473819242496  1311093473819242496
# ...

# %%
df['full_text'][16]
# Out:
# 'RT @AdamComedian: I hope Joe Biden has an earpiece tonight and some 15 year old kid hacks it and has him saying the lyrics to WAP.'

# %%
df['biden'][16]
# Out:
# True

# %%
df['postrump'] = (True if (df['trump'] == True) and df['biden'] == False and (df['vader_compound'] > 0) else False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-c45b31e8735b> in <module>
# ----> 1 df['postrump'] = (True if (df['trump'] == True) and  (df['vader_compound'] > 0) else False)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
True*True
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
False*False
# Out:
# 0

# %%
df_t = df[df['trump']==True]

# %%
df_t
# Out:
#                       created_at                   id               id_str  \
# 2      2020-09-30 00:00:00+00:00  1311093401652277252  1311093401652277248
# 5      2020-09-30 00:00:06+00:00  1311093427434446853  1311093427434446848
# 6      2020-09-30 00:00:08+00:00  1311093435844222982  1311093435844222976
# 10     2020-09-30 00:00:15+00:00  1311093465682386944  1311093465682386944
# 17     2020-09-30 00:00:29+00:00  1311093523794591744  1311093523794591744
# ...                          ...                  ...                  ...
# 140319 2020-10-02 23:59:30+00:00  1312180440497750016  1312180440497750016
# 140320 2020-10-02 23:58:58+00:00  1312180306380648448  1312180306380648448
# 140321 2020-10-02 23:59:22+00:00  1312180406930694144  1312180406930694144
# 140322 2020-10-02 23:59:37+00:00  1312180469362950144  1312180469362950144
# 140335 2020-10-02 23:59:41+00:00  1312180486840619008  1312180486840619008
#
# ...

# %%
df_ot = df_t[df_t['biden']==False]

# %%
df_ot
# Out:
#                       created_at                   id               id_str  \
# 5      2020-09-30 00:00:06+00:00  1311093427434446853  1311093427434446848
# 10     2020-09-30 00:00:15+00:00  1311093465682386944  1311093465682386944
# 17     2020-09-30 00:00:29+00:00  1311093523794591744  1311093523794591744
# 24     2020-09-30 00:00:42+00:00  1311093578563641344  1311093578563641344
# 25     2020-09-30 00:00:44+00:00  1311093586692386816  1311093586692386816
# ...                          ...                  ...                  ...
# 140308 2020-10-02 23:59:32+00:00  1312180448630464512  1312180448630464512
# 140319 2020-10-02 23:59:30+00:00  1312180440497750016  1312180440497750016
# 140320 2020-10-02 23:58:58+00:00  1312180306380648448  1312180306380648448
# 140322 2020-10-02 23:59:37+00:00  1312180469362950144  1312180469362950144
# 140335 2020-10-02 23:59:41+00:00  1312180486840619008  1312180486840619008
#
# ...

# %%
df_otpos = df_ot[df_ot['vader_compound'] >= .05]

# %%
df_otpos
# Out:
#                       created_at                   id               id_str  \
# 25     2020-09-30 00:00:44+00:00  1311093586692386816  1311093586692386816
# 30     2020-09-30 00:00:53+00:00  1311093624843595776  1311093624843595776
# 42     2020-09-30 00:01:15+00:00  1311093717412073473  1311093717412073472
# 50     2020-09-30 00:01:30+00:00  1311093780586602496  1311093780586602496
# 55     2020-09-30 00:01:40+00:00  1311093821736878081  1311093821736878080
# ...                          ...                  ...                  ...
# 140272 2020-10-02 23:57:59+00:00  1312180058585407489  1312180058585407488
# 140293 2020-10-02 23:58:36+00:00  1312180213845913600  1312180213845913600
# 140298 2020-10-02 23:58:44+00:00  1312180247299723265  1312180247299723264
# 140301 2020-10-02 23:58:49+00:00  1312180268078252033  1312180268078252032
# 140308 2020-10-02 23:59:32+00:00  1312180448630464512  1312180448630464512
#
# ...

# %%
df_otneg = df_ot[df_ot['vader_compound'] <= -.05]

# %%
df_otneg.reset_index()['full_text'][0]
# Out:
# 'RT @ASlavitt: BREAKING: 7 former bipartisan FDA commissioners including former Trump commissioner condemn Trump administration politicizati…'
