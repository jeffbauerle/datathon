# %%
import pandas as pd
import json
pd.set_option('display.max_columns', None)

# %%
df = pd.read_json('../data/concatenated_abridged.jsonl', lines = True)

# %%
df.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2020-09-29 23:59:56+00:00  1311093385688735744  1311093385688735744
# 1 2020-09-29 23:59:58+00:00  1311093394400333824  1311093394400333824
# 2 2020-09-30 00:00:00+00:00  1311093401652277252  1311093401652277248
# 3 2020-09-30 00:00:02+00:00  1311093410737070086  1311093410737070080
# 4 2020-09-30 00:00:04+00:00  1311093419100561408  1311093419100561408
#
#                                            full_text  truncated  \
# 0  Biden a professional debater??  Hardly!! More ...      False
# 1  RT @DarDar458: #PresidentialDebate #Debates202...      False
# 2  How can Biden stand a chance against Trump in ...      False
# 3  RT @abbydphillip: Very reminiscent of pre-2018...      False
# 4  RT @RudyGiuliani: Why was Corrupt Biden’s son ...      False
#
#   display_text_range                                           entities  \
# 0            [0, 71]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1            [0, 73]  {'hashtags': [{'text': 'PresidentialDebate', '...
# 2           [0, 280]  {'hashtags': [{'text': 'VarneyCo', 'indices': ...
# 3           [0, 108]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [0, 110]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 1  <a href="http://twitter.com/download/iphone" r...                    NaN
# 2  <a href="https://studio.twitter.com" rel="nofo...                    NaN
# 3  <a href="http://twitter.com/download/iphone" r...                    NaN
# 4  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    in_reply_to_status_id_str  in_reply_to_user_id  in_reply_to_user_id_str  \
# 0                        NaN                  NaN                      NaN
# 1                        NaN                  NaN                      NaN
# 2                        NaN                  NaN                      NaN
# 3                        NaN                  NaN                      NaN
# 4                        NaN                  NaN                      NaN
#
#   in_reply_to_screen_name                                               user  \
# 0                    None  {'id': 117904481, 'id_str': '117904481', 'name...
# 1                    None  {'id': 30140760, 'id_str': '30140760', 'name':...
# 2                    None  {'id': 281610530, 'id_str': '281610530', 'name...
# 3                    None  {'id': 88223320, 'id_str': '88223320', 'name':...
# 4                    None  {'id': 44295160, 'id_str': '44295160', 'name':...
#
#     geo coordinates place  contributors  is_quote_status  quoted_status_id  \
# 0  None        None  None           NaN             True      1.311081e+18
# 1  None        None  None           NaN             True      1.311068e+18
# 2  None        None  None           NaN            False               NaN
# 3  None        None  None           NaN             True      1.311075e+18
# 4  None        None  None           NaN            False               NaN
#
#    quoted_status_id_str                            quoted_status_permalink  \
# 0          1.311081e+18  {'url': 'https://t.co/cQuxzexXYt', 'expanded':...
# 1          1.311068e+18  {'url': 'https://t.co/GOhLaDJLeN', 'expanded':...
# 2                   NaN                                                NaN
# 3          1.311075e+18  {'url': 'https://t.co/CdP89boyMD', 'expanded':...
# 4                   NaN                                                NaN
#
#                                        quoted_status  retweet_count  \
# 0  {'created_at': 'Tue Sep 29 23:12:13 +0000 2020...              0
# 1                                                NaN              1
# 2                                                NaN             25
# 3                                                NaN            351
# 4                                                NaN          15672
#
#    favorite_count  favorited  retweeted  possibly_sensitive lang  \
# 0               0      False      False                 0.0   en
# 1               0      False      False                 NaN  und
# 2             100      False      False                 0.0   en
# 3               0      False      False                 NaN   en
# 4               0      False      False                 NaN   en
#
#                                     retweeted_status  \
# 0                                                NaN
# 1  {'created_at': 'Tue Sep 29 23:55:42 +0000 2020...
# 2                                                NaN
# 3  {'created_at': 'Tue Sep 29 23:00:28 +0000 2020...
# 4  {'created_at': 'Tue Sep 29 19:07:59 +0000 2020...
#
#                                    extended_entities withheld_in_countries
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2  {'media': [{'id': 1310969778111217665, 'id_str...                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN

# %%
df.entities[0]
# Out:
# {'hashtags': [],
#  'symbols': [],
#  'user_mentions': [],
#  'urls': [{'url': 'https://t.co/cQuxzexXYt',
#    'expanded_url': 'https://twitter.com/IngrahamAngle/status/1311081374510710784',
#    'display_url': 'twitter.com/IngrahamAngle/…',
#    'indices': [72, 95]}]}

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
def analyze_sentiment(text_str):
    vs = analyzer.polarity_scores(text_str)
    return vs

def vader_neg(text_str):
    vs = analyzer.polarity_scores(text_str)
    return vs['neg']


def vader_neu(text_str):
    vs = analyzer.polarity_scores(text_str)
    return vs['neu']

def vader_pos(text_str):
    vs = analyzer.polarity_scores(text_str)
    return vs['pos']
    
def vader_compound(text_str):
    vs = analyzer.polarity_scores(text_str)
    return vs['compound']

# %%
analyze_sentiment('I feel good')
# Out:
# {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}

# %%
vader_neg('I feel terrible')
# Out:
# 0.608

# %%
df['vader_neg'] = df['full_text'].apply(vader_neg)

# %%
df['vader_pos'] = df['full_text'].apply(vader_pos)
df['vader_neu'] = df['full_text'].apply(vader_neu)
df['vader_compound'] = df['full_text'].apply(vader_compound)

# %%
def detect_trump(string):
    lower = string.lower()
    split = lower.split()
    for word in split:
        if 'trump' in split:
            return True
        if '#trump' in split:
            return True
    else:
        return False

# %%
def detect_biden(string):
    lower = string.lower()
    split = lower.split()
    for word in split:
        if 'biden' in split:
            return True
        if '#biden' in split:
            return True
    else:
        return False

# %%
def detect_obama(string):
    lower = string.lower()
    split = lower.split()
    for word in split:
        if 'obama' in split:
            return True
        if '#obama' in split:
            return True
    else:
        return False

# %%
def detect_clinton(string):
    lower = string.lower()
    split = lower.split()
    for word in split:
        if 'clinton' in split:
            return True
        if '#clinton' in split:
            return True
        if 'hillary' in split:
            return True
        if '#hillary' in split:
            return True
    else:
        return False

# %%
def detect_bush(string):
    lower = string.lower()
    split = lower.split()
    for word in split:
        if 'bush' in split:
            return True
        if '#bush' in split:
            return True
    else:
        return False

# %%
detect_trump('trmp')
# Out:
# False

# %%
x
# Out:
# True

# %%
df['trump'] = df['full_text'].apply(detect_trump)

# %%
df['biden'] = df['full_text'].apply(detect_biden)

# %%
df['obama'] = df['full_text'].apply(detect_obama)

# %%
df['clinton'] = df['full_text'].apply(detect_clinton)

# %%
df['bush'] = df['full_text'].apply(detect_bush)

# %%
df

# %%
df['user'][5][]
# Out:
# {'id': 824676296034693120,
#  'id_str': '824676296034693120',
#  'name': 'Tasha Danner',
#  'screen_name': 'thetashadanner',
#  'location': 'Portland, OR',
#  'description': 'Political science nerd | Lover of this planet | Fears for the loss of democracy and the death of nuance. | Occasional singer, dancer & tickler of ivories.',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 217,
#  'friends_count': 660,
#  'listed_count': 3,
#  'created_at': 'Thu Jan 26 17:52:05 +0000 2017',
#  'favourites_count': 806,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 1286,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1308579596976021504/pHhxFB-1_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308579596976021504/pHhxFB-1_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/824676296034693120/1600470802',
#  'profile_image_extensions_alt_text': None,
#  'profile_banner_extensions_alt_text': None,
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
df['user'][5]['name']
# Out:
# 'Tasha Danner'

# %%
df['user'][5]['followers_count']
# Out:
# 217

# %%
df['user'][5]['friends_count']
# Out:
# 660

# %%
df['user'][0]['screen_name']
# Out:
# 'IngrahamAngle'

# %%
df['entities'][1]
# Out:
# {'hashtags': [{'text': 'PresidentialDebate', 'indices': [15, 34]},
#   {'text': 'Debates2020', 'indices': [35, 47]},
#   {'text': 'TrumpIsANationalDisgrace', 'indices': [48, 73]}],
#  'symbols': [],
#  'user_mentions': [{'screen_name': 'DarDar458',
#    'name': 'DarDar45 🌊 🆘',
#    'id': 1084234892840484864,
#    'id_str': '1084234892840484864',
#    'indices': [3, 13]}],
#  'urls': []}

# %%
df['full_text'][3]
# Out:
# 'RT @abbydphillip: Very reminiscent of pre-2018 election raids that coincided with Trump\'s "caravan" message.'

# %%
df['user'][25]
# Out:
# {'id': 1304109419526057984,
#  'id_str': '1304109419526057984',
#  'name': 'Bud COLLINS',
#  'screen_name': 'BudCOLLINS12',
#  'location': '',
#  'description': 'Man of God, love this President, love my wife of 54 years, MAGA, Trump 2020 baby, KAG, very conservative, and Jesus is Lord.',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 223,
#  'friends_count': 364,
#  'listed_count': 0,
#  'created_at': 'Thu Sep 10 17:28:28 +0000 2020',
#  'favourites_count': 1927,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 5160,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1304109702943473664/BpFQg8vq_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1304109702943473664/BpFQg8vq_normal.jpg',
#  'profile_image_extensions_alt_text': None,
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
def get_handle(d):
    return d['screen_name']

def get_followers(d):
    return d['followers_count']

def get_friends(d):
    return d['friends_count']

def get_statuses(d):
    return d['statuses_count']

def get_creation_date(d):
    return d['created_at']
    
def get_location(d):
    return d['location']

def get_acct_favs(d):
    return d['favourites_count']

# %%
df['friends'] = df['user'].apply(get_friends)

# %%
df['status count'] = df['user'].apply(get_statuses)

# %%
df['followers'] = df['user'].apply(get_followers)

# %%
df['creation date'] = df['user'].apply(get_creation_date)

# %%
df['handle'] = df['user'].apply(get_handle)

# %%
df['location'] = df['user'].apply(get_location)

# %%
df['acct favs'] = df['user'].apply(get_acct_favs)

# %%
'12093'.isalpha()
# Out:
# False

# %%
def suspect_name(name):
    return name[-5:].isnumeric()

# %%
suspect_name('taylor122109')
# Out:
# True

# %%
df['trailingnumbers'] = df['handle'].apply(suspect_name)

# %%
df[df['trailingnumbers']]
# Out:
#                       created_at                   id               id_str  \
# 29     2020-09-30 00:00:51+00:00  1311093616551448576  1311093616551448576
# 36     2020-09-30 00:01:04+00:00  1311093671022878720  1311093671022878720
# 41     2020-09-30 00:01:14+00:00  1311093710361374721  1311093710361374720
# 42     2020-09-30 00:01:15+00:00  1311093717412073473  1311093717412073472
# 46     2020-09-30 00:01:23+00:00  1311093750425432064  1311093750425432064
# ...                          ...                  ...                  ...
# 140276 2020-10-02 23:58:06+00:00  1312180087698018305  1312180087698018304
# 140298 2020-10-02 23:58:44+00:00  1312180247299723265  1312180247299723264
# 140315 2020-10-02 23:59:54+00:00  1312180541374963712  1312180541374963712
# 140318 2020-10-02 23:59:50+00:00  1312180523339378688  1312180523339378688
# 140329 2020-10-02 23:59:46+00:00  1312180507719860224  1312180507719860224
#
#                                                 full_text  truncated  \
# 29      RT @MsSunshineVee: @ThrottleJockey6 @jeremynew...      False
# 36      RT @ASlavitt: BREAKING: 7 former bipartisan FD...      False
# 41      RT @AndrewYang: Joe has been through 11 debate...      False
# 42      RT @DavidLimbaugh: As we go into tonight’s deb...      False
# 46      RT @TrumpWarRoom: 10. Biden claimed his Helico...      False
# ...                                                   ...        ...
# 140276  @chrisrogers20 @DavidJHarrisJr @realDonaldTrum...      False
# 140298  RT @JevonWilliamsVI: Just saw President Trump ...      False
# 140315  RT @catturd2: I'm glad Joe and Jill Biden have...      False
# 140318  RT @realDonaldTrump: Tonight, @FLOTUS and I te...      False
# 140329  RT @cadenbrackett: @JoeBiden Come together and...      False
#
#        display_text_range                                           entities  \
# 29               [0, 144]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 36               [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 41                [0, 83]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 42               [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 46               [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...                   ...                                                ...
# 140276          [48, 114]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 140298           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 140315           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 140318           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 140329           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                                    source  \
# 29      <a href="https://mobile.twitter.com" rel="nofo...
# 36      <a href="http://twitter.com/download/iphone" r...
# 41      <a href="http://twitter.com/download/android" ...
# 42      <a href="http://twitter.com/download/android" ...
# 46      <a href="https://mobile.twitter.com" rel="nofo...
# ...                                                   ...
# 140276  <a href="http://twitter.com/download/iphone" r...
# 140298  <a href="http://twitter.com/download/iphone" r...
# 140315  <a href="http://twitter.com/download/iphone" r...
# 140318  <a href="http://twitter.com/download/android" ...
# 140329  <a href="http://twitter.com/download/android" ...
#
#         in_reply_to_status_id  in_reply_to_status_id_str  in_reply_to_user_id  \
# 29                        NaN                        NaN                  NaN
# 36                        NaN                        NaN                  NaN
# 41                        NaN                        NaN                  NaN
# 42                        NaN                        NaN                  NaN
# 46                        NaN                        NaN                  NaN
# ...                       ...                        ...                  ...
# 140276           1.312179e+18               1.312179e+18          374675124.0
# 140298                    NaN                        NaN                  NaN
# 140315                    NaN                        NaN                  NaN
# 140318                    NaN                        NaN                  NaN
# 140329                    NaN                        NaN                  NaN
#
#         in_reply_to_user_id_str in_reply_to_screen_name  \
# 29                          NaN                    None
# 36                          NaN                    None
# 41                          NaN                    None
# 42                          NaN                    None
# 46                          NaN                    None
# ...                         ...                     ...
# 140276              374675124.0           chrisrogers20
# 140298                      NaN                    None
# 140315                      NaN                    None
# 140318                      NaN                    None
# 140329                      NaN                    None
#
#                                                      user   geo coordinates  \
# 29      {'id': 1132994442145570817, 'id_str': '1132994...  None        None
# 36      {'id': 713100350618664960, 'id_str': '71310035...  None        None
# 41      {'id': 1288303468151803909, 'id_str': '1288303...  None        None
# 42      {'id': 388682535, 'id_str': '388682535', 'name...  None        None
# 46      {'id': 1280295016045383681, 'id_str': '1280295...  None        None
# ...                                                   ...   ...         ...
# 140276  {'id': 839240570895740928, 'id_str': '83924057...  None        None
# 140298  {'id': 1300518219820732417, 'id_str': '1300518...  None        None
# 140315  {'id': 973893718049808384, 'id_str': '97389371...  None        None
# 140318  {'id': 1276182117903405056, 'id_str': '1276182...  None        None
# 140329  {'id': 1171587345096818688, 'id_str': '1171587...  None        None
#
#        place  contributors  is_quote_status  quoted_status_id  \
# 29      None           NaN            False               NaN
# 36      None           NaN            False               NaN
# 41      None           NaN            False               NaN
# 42      None           NaN            False               NaN
# 46      None           NaN            False               NaN
# ...      ...           ...              ...               ...
# 140276  None           NaN            False               NaN
# 140298  None           NaN            False               NaN
# 140315  None           NaN            False               NaN
# 140318  None           NaN            False               NaN
# 140329  None           NaN            False               NaN
#
#         quoted_status_id_str quoted_status_permalink quoted_status  \
# 29                       NaN                     NaN           NaN
# 36                       NaN                     NaN           NaN
# 41                       NaN                     NaN           NaN
# 42                       NaN                     NaN           NaN
# 46                       NaN                     NaN           NaN
# ...                      ...                     ...           ...
# 140276                   NaN                     NaN           NaN
# 140298                   NaN                     NaN           NaN
# 140315                   NaN                     NaN           NaN
# 140318                   NaN                     NaN           NaN
# 140329                   NaN                     NaN           NaN
#
#         retweet_count  favorite_count  favorited  retweeted  \
# 29                  1               0      False      False
# 36               1844               0      False      False
# 41                385               0      False      False
# 42                519               0      False      False
# 46                324               0      False      False
# ...               ...             ...        ...        ...
# 140276              1               1      False      False
# 140298            110               0      False      False
# 140315           2813               0      False      False
# 140318         412154               0      False      False
# 140329              5               0      False      False
#
#         possibly_sensitive lang  \
# 29                     NaN   en
# 36                     NaN   en
# 41                     NaN   en
# 42                     NaN   en
# 46                     NaN   en
# ...                    ...  ...
# 140276                 NaN   en
# 140298                 NaN   en
# 140315                 NaN   en
# 140318                 NaN   en
# 140329                 NaN   en
#
#                                          retweeted_status extended_entities  \
# 29      {'created_at': 'Tue Sep 29 23:56:49 +0000 2020...               NaN
# 36      {'created_at': 'Tue Sep 29 23:22:21 +0000 2020...               NaN
# 41      {'created_at': 'Tue Sep 29 23:16:07 +0000 2020...               NaN
# 42      {'created_at': 'Tue Sep 29 23:52:05 +0000 2020...               NaN
# 46      {'created_at': 'Tue Sep 29 23:40:00 +0000 2020...               NaN
# ...                                                   ...               ...
# 140276                                                NaN               NaN
# 140298  {'created_at': 'Fri Oct 02 22:35:26 +0000 2020...               NaN
# 140315  {'created_at': 'Fri Oct 02 23:57:04 +0000 2020...               NaN
# 140318  {'created_at': 'Fri Oct 02 04:54:06 +0000 2020...               NaN
# 140329  {'created_at': 'Fri Oct 02 23:21:12 +0000 2020...               NaN
#
#        withheld_in_countries  vader_neg  vader_pos  vader_neu  vader_compound  \
# 29                       NaN      0.158      0.190      0.652          0.1904
# 36                       NaN      0.148      0.000      0.852         -0.3818
# 41                       NaN      0.000      0.000      1.000          0.0000
# 42                       NaN      0.000      0.266      0.734          0.7650
# 46                       NaN      0.231      0.000      0.769         -0.7184
# ...                      ...        ...        ...        ...             ...
# 140276                   NaN      0.160      0.000      0.840         -0.2263
# 140298                   NaN      0.000      0.260      0.740          0.7500
# 140315                   NaN      0.291      0.089      0.620         -0.7819
# 140318                   NaN      0.000      0.159      0.841          0.5574
# 140329                   NaN      0.269      0.000      0.731         -0.7906
#
#         trump  biden  obama  clinton   bush           handle  followers  \
# 29      False  False  False    False  False     Odie11716715       2340
# 36       True  False  False    False  False  Melissa23042148        139
# 41      False  False  False    False  False   Sherri83702120         60
# 42       True  False  False    False  False     ronnie122090       1456
# 46      False   True  False    False  False   Aussie26619825        133
# ...       ...    ...    ...      ...    ...              ...        ...
# 140276  False  False  False    False  False    Kmari34461773       2459
# 140298   True  False  False    False  False  BonnieM88179435        141
# 140315  False   True  False    False  False  JudyYor36206738       2291
# 140318  False  False  False    False  False  Namenot16266383        278
# 140329  False  False  False    False  False  TimConw66864227        170
#
#         friends  status count                   creation date  \
# 29         3127         70824  Mon May 27 12:58:19 +0000 2019
# 36          436         44189  Thu Mar 24 20:29:07 +0000 2016
# 41          240         11538  Wed Jul 29 02:41:09 +0000 2020
# 42         2199         15798  Tue Oct 11 05:01:03 +0000 2011
# 46          420         11483  Tue Jul 07 00:18:39 +0000 2020
# ...         ...           ...                             ...
# 140276     2100         77789  Tue Mar 07 22:25:19 +0000 2017
# 140298      367          1645  Mon Aug 31 19:39:23 +0000 2020
# 140315     5002         52855  Wed Mar 14 12:08:51 +0000 2018
# 140318      266          7915  Thu Jun 25 15:55:24 +0000 2020
# 140329      245          5659  Wed Sep 11 00:53:14 +0000 2019
#
#                             location  acct favs  trailingnumbers
# 29                                        72753             True
# 36                                       101531             True
# 41                                        15555             True
# 42                        Chester VA      33988             True
# 46                                         9777             True
# ...                              ...        ...              ...
# 140276                                   105461             True
# 140298                                     1317             True
# 140315                                    46258             True
# 140318  Far away from Liberal idiots       9819             True
# 140329                                     5532             True
#
# [10834 rows x 49 columns]
