# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

plt.style.use('fivethirtyeight')

# %%
trump_df = pd.read_csv('../data/trumptweets.csv')

# %%
trump_df
# Out:
#                         id                                               text  \
# 0        98454970654916608  Republicans and Democrats have both created ou...
# 1      1234653427789070336  I was thrilled to be back in the Great city of...
# 2      1218010753434820614  RT @CBS_Herridge: READ: Letter to surveillance...
# 3      1304875170860015617  The Unsolicited Mail In Ballot Scam is a major...
# 4      1218159531554897920  RT @MZHemingway: Very friendly telling of even...
# ...                    ...                                                ...
# 54437  1319484210101379072  RT @EliseStefanik: President @realDonaldTrump ...
# 54438  1319444420861829121  RT @TeamTrump: LIVE: Presidential Debate #Deba...
# 54439  1319384118849949702  Just signed an order to support the workers of...
# 54440  1319345719829008387  Suburban women want Safety &amp; Security. Joe...
# 54441  1319339440867741696  Just left the White House for the Great State ...
#
#       isRetweet isDeleted              device  favorites  retweets  \
# 0             f         f           TweetDeck         49       255
# 1             f         f  Twitter for iPhone      73748     17404
# 2             t         f  Twitter for iPhone          0      7396
# 3             f         f  Twitter for iPhone      80527     23502
# 4             t         f  Twitter for iPhone          0      9081
# ...         ...       ...                 ...        ...       ...
# 54437         t         f  Twitter for iPhone          0      9912
# 54438         t         f  Twitter for iPhone          0      8249
# 54439         f         f  Twitter for iPhone     175950     36098
# 54440         f         f  Twitter for iPhone      95325     19639
# 54441         f         f  Twitter for iPhone     137363     20791
#
#                       date
# 0      2011-08-02 18:07:48
# 1      2020-03-03 01:34:50
# 2      2020-01-17 03:22:47
# 3      2020-09-12 20:10:58
# 4      2020-01-17 13:13:59
# ...                    ...
# 54437  2020-10-23 03:42:05
# 54438  2020-10-23 01:03:58
# 54439  2020-10-22 21:04:21
# 54440  2020-10-22 18:31:46
# 54441  2020-10-22 18:06:49
#
# [54442 rows x 8 columns]

# %%
trump_df['date'].min()
# Out:
# '2009-05-04 18:54:25'

# %%
trump_df['date'].max()
# Out:
# '2020-10-24 20:13:08'

# %%
def analyze_sentiment(text_str):
    vs = analyzer.polarity_scores(text_str)
    return vs

# %%
def vader_compound(text_str):
    vs = analyzer.polarity_scores(text_str)
    return vs['compound']

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
trump_df['vader_sent'] = trump_df['text'].apply(analyze_sentiment)

# %%
trump_df['vader_comp'] = trump_df['text'].apply(vader_compound)

# %%
trump_df['vader_sent'][0]
# Out:
# {'neg': 0.231, 'neu': 0.598, 'pos': 0.171, 'compound': -0.1779}

# %%
def vader_compound(text_str):
    vs = analyzer.polarity_scores(text_str)
    return vs['compound']

# %%
trump_df
# Out:
#                         id                                               text  \
# 0        98454970654916608  Republicans and Democrats have both created ou...
# 1      1234653427789070336  I was thrilled to be back in the Great city of...
# 2      1218010753434820614  RT @CBS_Herridge: READ: Letter to surveillance...
# 3      1304875170860015617  The Unsolicited Mail In Ballot Scam is a major...
# 4      1218159531554897920  RT @MZHemingway: Very friendly telling of even...
# ...                    ...                                                ...
# 54437  1319484210101379072  RT @EliseStefanik: President @realDonaldTrump ...
# 54438  1319444420861829121  RT @TeamTrump: LIVE: Presidential Debate #Deba...
# 54439  1319384118849949702  Just signed an order to support the workers of...
# 54440  1319345719829008387  Suburban women want Safety &amp; Security. Joe...
# 54441  1319339440867741696  Just left the White House for the Great State ...
#
#       isRetweet isDeleted              device  favorites  retweets  \
# 0             f         f           TweetDeck         49       255
# 1             f         f  Twitter for iPhone      73748     17404
# 2             t         f  Twitter for iPhone          0      7396
# 3             f         f  Twitter for iPhone      80527     23502
# 4             t         f  Twitter for iPhone          0      9081
# ...         ...       ...                 ...        ...       ...
# 54437         t         f  Twitter for iPhone          0      9912
# 54438         t         f  Twitter for iPhone          0      8249
# 54439         f         f  Twitter for iPhone     175950     36098
# 54440         f         f  Twitter for iPhone      95325     19639
# 54441         f         f  Twitter for iPhone     137363     20791
#
#                       date                                         vader_sent  \
# 0      2011-08-02 18:07:48  {'neg': 0.231, 'neu': 0.598, 'pos': 0.171, 'co...
# 1      2020-03-03 01:34:50  {'neg': 0.0, 'neu': 0.567, 'pos': 0.433, 'comp...
# 2      2020-01-17 03:22:47  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3      2020-09-12 20:10:58  {'neg': 0.288, 'neu': 0.712, 'pos': 0.0, 'comp...
# 4      2020-01-17 13:13:59  {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'comp...
# ...                    ...                                                ...
# 54437  2020-10-23 03:42:05  {'neg': 0.0, 'neu': 0.837, 'pos': 0.163, 'comp...
# 54438  2020-10-23 01:03:58  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 54439  2020-10-22 21:04:21  {'neg': 0.172, 'neu': 0.677, 'pos': 0.151, 'co...
# 54440  2020-10-22 18:31:46  {'neg': 0.0, 'neu': 0.618, 'pos': 0.382, 'comp...
# 54441  2020-10-22 18:06:49  {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'comp...
#
#        vader_comp
# 0         -0.1779
# 1          0.9792
# 2          0.0000
# 3         -0.9571
# 4          0.5413
# ...           ...
# 54437      0.5423
# 54438      0.0000
# 54439     -0.4678
# 54440      0.6996
# 54441      0.6588
#
# [54442 rows x 10 columns]

# %%
trump_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54442 entries, 0 to 54441
# Data columns (total 10 columns):
# id            54442 non-null int64
# text          54442 non-null object
# isRetweet     54442 non-null object
# isDeleted     54442 non-null object
# device        54442 non-null object
# favorites     54442 non-null int64
# retweets      54442 non-null int64
# date          54442 non-null object
# vader_sent    54442 non-null object
# vader_comp    54442 non-null float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 4.2+ MB

# %%
trump_df['datetime'] = pd.to_datetime(trump_df['date'])

# %%
trump_df['datetime']
# Out:
# 0       2011-08-02 18:07:48
# 1       2020-03-03 01:34:50
# 2       2020-01-17 03:22:47
# 3       2020-09-12 20:10:58
# 4       2020-01-17 13:13:59
#                 ...
# 54437   2020-10-23 03:42:05
# 54438   2020-10-23 01:03:58
# 54439   2020-10-22 21:04:21
# 54440   2020-10-22 18:31:46
# 54441   2020-10-22 18:06:49
# Name: datetime, Length: 54442, dtype: datetime64[ns]

# %%
trump_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54442 entries, 0 to 54441
# Data columns (total 11 columns):
# id            54442 non-null int64
# text          54442 non-null object
# isRetweet     54442 non-null object
# isDeleted     54442 non-null object
# device        54442 non-null object
# favorites     54442 non-null int64
# retweets      54442 non-null int64
# date          54442 non-null object
# vader_sent    54442 non-null object
# vader_comp    54442 non-null float64
# datetime      54442 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(3), object(6)
# memory usage: 4.6+ MB

# %%
fig, ax = plt.subplots(figsize=(20, 12))
ax.scatter(trump_df.datetime, trump_df.vader_comp)
ax.set_xlabel('Date', fontsize=18)
ax.set_ylabel('Compound Sentiment', fontsize=18)
ax.set_title('My Trump Mood Board: Compound Sentiment (All Tweets)', fontsize=25)
ax.grid(True)
plt.savefig('../images/compiled_trump_mood.png')

# %%
def vader_neg(text_str):
    vs = analyzer.polarity_scores(text_str)
    return vs['neg']

def vader_neu(text_str):
    vs = analyzer.polarity_scores(text_str)
    return vs['neu']

def vader_pos(text_str):
    vs = analyzer.polarity_scores(text_str)
    return vs['pos']
    
def vader_compound(text_str):
    vs = analyzer.polarity_scores(text_str)
    return vs['compound']

# %%
trump_df['vader_neg'] = trump_df['text'].apply(vader_neg)
trump_df['vader_pos'] = trump_df['text'].apply(vader_pos)
trump_df['vader_neu'] = trump_df['text'].apply(vader_neu)

# %%
plt.rc('font', size=12)
fig, ax = plt.subplots(figsize=(20, 12))

ax.scatter(trump_df.datetime, trump_df.vader_neg, )
ax.set_xlabel('Date', fontsize=18)
ax.set_ylabel('Vader Negative Sentiment', fontsize=18)
ax.set_title('My Trump Mood Board – Tweets by Negative Sentiment', fontsize=25)
ax.grid(True)
ax.legend(loc='upper left');
plt.savefig('../images/negative_trump_mood.png')
# Out:
# No handles with labels found to put in legend.

# %%
plt.rc('font', size=12)
fig, ax = plt.subplots(figsize=(20, 12))
ax.scatter(trump_df.datetime, trump_df.vader_pos)
ax.set_xlabel('Date', fontsize=18)
ax.set_ylabel('Vader Positive Sentiment', fontsize=18)
ax.set_title('My Trump Mood Board – Tweets by Positive Sentiment', fontsize=25)
ax.grid(True)
ax.legend(loc='upper left');
plt.savefig('../images/positive_trump_mood.png')
# Out:
# No handles with labels found to put in legend.

# %%
trump_df[trump_df['vader_comp']!=0]
# Out:
#                         id                                               text  \
# 0        98454970654916608  Republicans and Democrats have both created ou...
# 1      1234653427789070336  I was thrilled to be back in the Great city of...
# 3      1304875170860015617  The Unsolicited Mail In Ballot Scam is a major...
# 4      1218159531554897920  RT @MZHemingway: Very friendly telling of even...
# 5      1319761576996573186  THANK YOU to all of the Great American Patriot...
# ...                    ...                                                ...
# 54436  1319485303363571714  RT @RandPaul: I don’t know why @JoeBiden think...
# 54437  1319484210101379072  RT @EliseStefanik: President @realDonaldTrump ...
# 54439  1319384118849949702  Just signed an order to support the workers of...
# 54440  1319345719829008387  Suburban women want Safety &amp; Security. Joe...
# 54441  1319339440867741696  Just left the White House for the Great State ...
#
#       isRetweet isDeleted              device  favorites  retweets  \
# 0             f         f           TweetDeck         49       255
# 1             f         f  Twitter for iPhone      73748     17404
# 3             f         f  Twitter for iPhone      80527     23502
# 4             t         f  Twitter for iPhone          0      9081
# 5             f         f  Twitter for iPhone     100564     18992
# ...         ...       ...                 ...        ...       ...
# 54436         t         f  Twitter for iPhone          0     20645
# 54437         t         f  Twitter for iPhone          0      9912
# 54439         f         f  Twitter for iPhone     175950     36098
# 54440         f         f  Twitter for iPhone      95325     19639
# 54441         f         f  Twitter for iPhone     137363     20791
#
#                       date                                         vader_sent  \
# 0      2011-08-02 18:07:48  {'neg': 0.231, 'neu': 0.598, 'pos': 0.171, 'co...
# 1      2020-03-03 01:34:50  {'neg': 0.0, 'neu': 0.567, 'pos': 0.433, 'comp...
# 3      2020-09-12 20:10:58  {'neg': 0.288, 'neu': 0.712, 'pos': 0.0, 'comp...
# 4      2020-01-17 13:13:59  {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'comp...
# 5      2020-10-23 22:04:14  {'neg': 0.0, 'neu': 0.63, 'pos': 0.37, 'compou...
# ...                    ...                                                ...
# 54436  2020-10-23 03:46:25  {'neg': 0.126, 'neu': 0.874, 'pos': 0.0, 'comp...
# 54437  2020-10-23 03:42:05  {'neg': 0.0, 'neu': 0.837, 'pos': 0.163, 'comp...
# 54439  2020-10-22 21:04:21  {'neg': 0.172, 'neu': 0.677, 'pos': 0.151, 'co...
# 54440  2020-10-22 18:31:46  {'neg': 0.0, 'neu': 0.618, 'pos': 0.382, 'comp...
# 54441  2020-10-22 18:06:49  {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'comp...
#
#        vader_comp            datetime  vader_neg  vader_pos  vader_neu
# 0         -0.1779 2011-08-02 18:07:48      0.231      0.171      0.598
# 1          0.9792 2020-03-03 01:34:50      0.000      0.433      0.567
# 3         -0.9571 2020-09-12 20:10:58      0.288      0.000      0.712
# 4          0.5413 2020-01-17 13:13:59      0.000      0.143      0.857
# 5          0.8236 2020-10-23 22:04:14      0.000      0.370      0.630
# ...           ...                 ...        ...        ...        ...
# 54436     -0.5574 2020-10-23 03:46:25      0.126      0.000      0.874
# 54437      0.5423 2020-10-23 03:42:05      0.000      0.163      0.837
# 54439     -0.4678 2020-10-22 21:04:21      0.172      0.151      0.677
# 54440      0.6996 2020-10-22 18:31:46      0.000      0.382      0.618
# 54441      0.6588 2020-10-22 18:06:49      0.000      0.285      0.715
#
# [44068 rows x 14 columns]

# %%
trump_df[trump_df['vader_comp'] ==0]
# Out:
#                         id                                               text  \
# 2      1218010753434820614  RT @CBS_Herridge: READ: Letter to surveillance...
# 7      1315779944002199552  “I’m running as a proud Democrat, for the Sena...
# 8      1223640662689689602  Getting a little exercise this morning! https:...
# 9      1319727996882702336                            https://t.co/LCQcdlRkhz
# 10     1319727773234069505                            https://t.co/4V7nu5hh8V
# ...                    ...                                                ...
# 54407  1079920504268562432  RT @WhiteHouse: 2018 has been a year of histor...
# 54420  1213316629666435072       RT @realDonaldTrump: https://t.co/VXeKiVzpTf
# 54421  1213316570606428160                            https://t.co/qOi7mpKcHY
# 54422  1213203275094405121  RT @WhiteHouse: A statement from President @re...
# 54438  1319444420861829121  RT @TeamTrump: LIVE: Presidential Debate #Deba...
#
#       isRetweet isDeleted              device  favorites  retweets  \
# 2             t         f  Twitter for iPhone          0      7396
# 7             f         f  Twitter for iPhone     149007     34897
# 8             f         f  Twitter for iPhone     285863     30209
# 9             f         f  Twitter for iPhone      54469     14126
# 10            f         f  Twitter for iPhone      54010     17481
# ...         ...       ...                 ...        ...       ...
# 54407         t         f  Twitter for iPhone          0     21477
# 54420         t         f  Twitter for iPhone          0    153868
# 54421         f         f  Twitter for iPhone     152920     22690
# 54422         t         f  Twitter for iPhone          0     49659
# 54438         t         f  Twitter for iPhone          0      8249
#
#                       date                                         vader_sent  \
# 2      2020-01-17 03:22:47  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7      2020-10-12 22:22:39  {'neg': 0.088, 'neu': 0.824, 'pos': 0.088, 'co...
# 8      2020-02-01 16:14:02  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9      2020-10-23 19:50:48  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 10     2020-10-23 19:49:55  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...                    ...                                                ...
# 54407  2019-01-01 02:01:26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 54420  2020-01-04 04:30:01  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 54421  2020-01-04 04:29:47  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 54422  2020-01-03 20:59:35  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 54438  2020-10-23 01:03:58  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
#        vader_comp            datetime  vader_neg  vader_pos  vader_neu
# 2             0.0 2020-01-17 03:22:47      0.000      0.000      1.000
# 7             0.0 2020-10-12 22:22:39      0.088      0.088      0.824
# 8             0.0 2020-02-01 16:14:02      0.000      0.000      1.000
# 9             0.0 2020-10-23 19:50:48      0.000      0.000      1.000
# 10            0.0 2020-10-23 19:49:55      0.000      0.000      1.000
# ...           ...                 ...        ...        ...        ...
# 54407         0.0 2019-01-01 02:01:26      0.000      0.000      1.000
# 54420         0.0 2020-01-04 04:30:01      0.000      0.000      1.000
# 54421         0.0 2020-01-04 04:29:47      0.000      0.000      1.000
# 54422         0.0 2020-01-03 20:59:35      0.000      0.000      1.000
# 54438         0.0 2020-10-23 01:03:58      0.000      0.000      1.000
#
# [10374 rows x 14 columns]

# %%
plt.rc('font', size=12)
fig, ax = plt.subplots(figsize=(20, 12))
ax.hist(trump_df.datetime, bins = 4191)
ax.set_xlabel('Date', fontsize=18)
ax.set_ylabel('Tweets', fontsize=18)
ax.set_title('How much is he tweeting? – Daily', fontsize=25)
ax.grid(True)
plt.savefig('../images/daily_tweet_count.png')

# %%
plt.rc('font', size=12)
fig, ax = plt.subplots(figsize=(20, 12))
ax.hist(trump_df.datetime, bins = 598)
ax.set_xlabel('Date', fontsize=18)
ax.set_ylabel('Tweets', fontsize=18)
ax.set_title('How much is he tweeting? – Weekly', fontsize=25)
ax.grid(True)
plt.savefig('../images/weekly_tweet_count.png')

# %%
plt.rc('font', size=12)
fig, ax = plt.subplots(figsize=(20, 12))

# Specify how our lines should look
ax.hist(trump_df.datetime, bins = 137)

# Same as above
ax.set_xlabel('Date')
ax.set_ylabel('Twets')
ax.set_title('How much is he tweeting? – Weekly' )
ax.grid(True)
ax.legend(loc='upper left');
# Out:
# No handles with labels found to put in legend.

# %%
del_df = trump_df[trump_df['isDeleted'] != 'f']

# %%
plt.rc('font', size=12)
fig, ax = plt.subplots(figsize=(20, 12))

# Specify how our lines should look
ax.scatter(del_df.datetime, del_df.vader_comp, c=del_df.vader_comp)

# Same as above
ax.set_xlabel('Date')
ax.set_ylabel('Compound Sentiment')
ax.set_title('My Trump Mood Board')
ax.grid(True)
ax.legend(loc='upper left');
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(figsize=(20, 12))

ax.hist(del_df.datetime, bins = 137)

# Same as above
ax.set_xlabel('Date', fontsize= 18)
ax.set_ylabel('Tweets (Count)', fontsize= 18)
ax.set_title('Deleted Trump Tweets – Weekly', fontsize= 25)
ax.grid(True)
plt.savefig('../images/weekly_del_tweet_count.png')

# %%
# Out:
# No handles with labels found to put in legend.

# %%
plt.rc('font', size=12)
fig, ax = plt.subplots(figsize=(20, 12))

# Specify how our lines should look
ax.scatter(trump_df.datetime, trump_df.favorites, c=trump_df.vader_comp)

# Same as above
ax.set_xlabel('Date')
ax.set_ylabel('Compound Sentiment')
ax.set_title('My Trump Mood Board – Favs')
ax.grid(True)
ax.legend(loc='upper left');
# Out:
# No handles with labels found to put in legend.

# %%
plt.rc('font', size=12)
fig, ax = plt.subplots(figsize=(20, 12))

ax.scatter(trump_df.datetime, trump_df.retweets, c=trump_df.vader_comp)
ax.set_xlabel('Date')
ax.set_ylabel('Compound Sentiment')
ax.set_title('My Trump Mood Board – Retweets')
ax.grid(True)
ax.legend(loc='upper left');
# Out:
# No handles with labels found to put in legend.

# %%
weekly_df_mean = trump_df.set_index('datetime').groupby(pd.Grouper(freq='W')).mean()
weekly_df_med = trump_df.set_index('datetime').groupby(pd.Grouper(freq='W')).median()
weekly_df_sum = trump_df.set_index('datetime').groupby(pd.Grouper(freq='W')).sum()

# %%
weekly_df_mean
# Out:
#                       id     favorites      retweets  vader_comp  vader_neg  \
# datetime
# 2009-05-10  1.719603e+09    316.000000    144.750000    0.485875   0.000000
# 2009-05-17  1.798018e+09    306.714286    210.428571    0.422300   0.009857
# 2009-05-24  1.866540e+09     63.857143     42.714286    0.430043   0.000000
# 2009-05-31  1.936665e+09     62.333333     39.666667    0.370600   0.000000
# 2009-06-07  2.032594e+09     26.500000     14.500000    0.196750   0.000000
# ...                  ...           ...           ...         ...        ...
# 2020-09-27  1.309156e+18  35110.525180  13507.205036    0.301448   0.038730
# 2020-10-04  1.311345e+18  80192.714286  23457.727679    0.016946   0.075853
# 2020-10-11  1.314031e+18  93256.382671  27266.036101    0.096725   0.070083
# 2020-10-18  1.316502e+18  51053.928731  18235.476615    0.137777   0.067677
# 2020-10-25  1.319282e+18  77105.974359  20967.789744    0.173943   0.058944
#
#             vader_pos  vader_neu
# datetime
# 2009-05-10   0.171250   0.828750
# 2009-05-17   0.191143   0.799143
# 2009-05-24   0.171714   0.828286
# 2009-05-31   0.173333   0.826667
# 2009-06-07   0.093000   0.907000
# ...               ...        ...
# 2020-09-27   0.157892   0.803363
# 2020-10-04   0.099246   0.824915
# 2020-10-11   0.125819   0.804087
# 2020-10-18   0.137782   0.794543
# 2020-10-25   0.143000   0.798077
#
# [599 rows x 7 columns]

# %%
weekly_df_med
# Out:
#                       id  favorites  retweets  vader_comp  vader_neg  \
# datetime
# 2009-05-10  1.719471e+09      148.0      24.5     0.58615        0.0
# 2009-05-17  1.796477e+09       33.0      19.0     0.48090        0.0
# 2009-05-24  1.864367e+09       61.0      32.0     0.58590        0.0
# 2009-05-31  1.936023e+09       59.0      49.0     0.36120        0.0
# 2009-06-07  2.032594e+09       26.5      14.5     0.19675        0.0
# ...                  ...        ...       ...         ...        ...
# 2020-09-27  1.309290e+18        0.0    9781.0     0.40190        0.0
# 2020-10-04  1.311343e+18    26967.5   14358.0     0.00000        0.0
# 2020-10-11  1.313843e+18    62006.0   20616.0     0.00000        0.0
# 2020-10-18  1.316392e+18    30180.0   13614.0     0.00000        0.0
# 2020-10-25  1.319384e+18    54843.0   15868.0     0.00000        0.0
#
#             vader_pos  vader_neu
# datetime
# 2009-05-10      0.212      0.788
# 2009-05-17      0.203      0.729
# 2009-05-24      0.192      0.808
# 2009-05-31      0.152      0.848
# 2009-06-07      0.093      0.907
# ...               ...        ...
# 2020-09-27      0.141      0.813
# 2020-10-04      0.000      0.853
# 2020-10-11      0.083      0.807
# 2020-10-18      0.088      0.809
# 2020-10-25      0.091      0.811
#
# [599 rows x 7 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 12))
ax.scatter(weekly_df_mean.index, weekly_df_mean.vader_comp, c=weekly_df_mean.vader_comp, s=200)
ax.set_xlabel('Date', fontsize = 18)
ax.set_ylabel('Vader Compound Sentiment', fontsize = 18)
ax.set_title('My Trump Mood Board – Weekly Mean Vader Compound Sentiment', fontsize=25)
ax.grid(True)
ax.legend(loc='upper left')
plt.savefig('../images/weekly_mean_comp_sent.png')
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(figsize=(20, 12))
ax.scatter(weekly_df_sum.index, weekly_df_sum.favorites, c=weekly_df_mean.vader_comp, s=200)
ax.set_xlabel('Date', fontsize=18)
ax.set_ylabel('Favorites, Total', fontsize=18)
ax.set_title('My Trump Mood Board – Weekly Favorites, Total', fontsize=25)
ax.grid(True)
plt.savefig('../images/weekly_sum_favs_total.png')
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(figsize=(20, 12))
ax.scatter(weekly_df_sum.index, weekly_df_sum.retweets, c=weekly_df_mean.vader_comp, s=200)
ax.set_xlabel('Date', fontsize=18)
ax.set_ylabel('Compound Sentiment', fontsize=18)
ax.set_title('My Trump Mood Board – Weekly Retweets, Total', fontsize=25)
ax.grid(True)
plt.savefig('../images/weekly_sum_retweets_total.png')

# %%
fig, ax = plt.subplots(figsize=(20, 12))
ax.scatter(weekly_df_mean.index, weekly_df_mean.favorites, c=weekly_df_mean.vader_comp, s=200)
ax.set_xlabel('Date', fontsize=18)
ax.set_ylabel('Average Weekly Favorites', fontsize=18)
ax.set_title('My Trump Mood Board – Weekly Favorites, Mean', fontsize=25)
ax.grid(True)
plt.savefig('../images/weekly_favorites_mean.png')

# %%
plt.rc('font', size=12)
fig, ax = plt.subplots(figsize=(20, 12))
ax.scatter(weekly_df_mean.index, weekly_df_mean.retweets, c=weekly_df_mean.vader_comp, s=200)
ax.set_xlabel('Date', fontsize=18)
ax.set_ylabel('Average Weekly Retweets', fontsize=18)
ax.set_title('My Trump Mood Board – Weekly Retweets, Mean', fontsize=25)
ax.grid(True)
plt.savefig('../images/weekly_retweets_mean.png')
